# %% [markdown]
# 1.	Write a Python program to take two numbers as input from the user and display their sum.**bold text**

# %%
num1 =float(input("Enter First Number:"))
num2 =float(input("Enter Second Number:"))
sum = num1 + num2
print("The sum of", num1, "and", num2, "is:", sum)
# Out:
# Enter First Number:12
# Enter Second Number:12
# The sum of 12.0 and 12.0 is: 24.0

# %% [markdown]
# 2.	Calculate and print the midpoint of two numbers entered by the user.

# %%
num1 = float(input("Enter First Number:"))
num2 = float(input("Enter Second Number:"))
midpoint = (num1+num2)/2
print("The Midpoint of", num1, "and", num2, "is:", midpoint)
# Out:
# Enter First Number:15
# Enter Second Number:15
# The Midpoint of 15.0 and 15.0 is: 15.0

# %% [markdown]
# 3.	Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.**bold text**

# %%
base = float (input("Enter base:"))
height = float (input("Enter height"))
area= 0.5*base*height
print("The area of:", area)
# Out:
# Enter base:10
# Enter height20
# The area of: 100.0

# %% [markdown]
# 4.	Take three numbers as input from the user and display their product.**bold text**

# %%
num1 = float(input("Enter First No:"))
num2 = float(input("Enter Second No:"))
num3 = float(input("Enter Third No:"))

Multiplication = num1 * num2 * num3
print ("Product of ", num1, "AND", num2, "AND", num3, "is:", Multiplication )
# Out:
# Enter First No:1
# Enter Second No:2
# Enter Third No:3
# Product of  1.0 AND 2.0 AND 3.0 is: 6.0

# %% [markdown]
# 5.	Take a number as input and display its square and cube.**bold text**

# %%
num = float(input("Enter a number: "))


square = num ** 2
cube = num ** 3


print("Square of the number is:", square)
print("Cube of the number is:", cube)
# Out:
# Enter a number: 9
# Square of the number is: 81.0
# Cube of the number is: 729.0

# %% [markdown]
# 6.	Take two numbers as input and display their quotient and remainder.**bold text**

# %%
num1 = int(input("Enter the dividend: "))
num2 = int(input("Enter the divisor: "))


quotient = num1 // num2
remainder = num1 % num2


print("Quotient:", quotient)
print("Remainder:", remainder)
# Out:
# Enter the dividend: 5
# Enter the divisor: 9
# Quotient: 0
# Remainder: 5

# %% [markdown]
# 7.	Take three numbers as input and display their average.**bold text**

# %%
num1 = int(input("Enter First No:"))
num2 = int(input("Enter Second No:"))
num3 = int(input("Enter Third No:"))

Avg = (num1 + num2 + num3) / 3
print ("Avg of ",Avg )
# Out:
# Enter First No:4
# Enter Second No:5
# Enter Third No:6
# Avg of  5.0

# %% [markdown]
# 8.	Write a Python program to calculate the area of a rectangle using the formula: area = length * width.**bold text**

# %%
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))


area = length * width


print("The area of the rectangle is:", area)
# Out:
# Enter the length of the rectangle: 6
# Enter the width of the rectangle: 8
# The area of the rectangle is: 48.0

# %% [markdown]
# 9.	Take five numbers as input representing marks obtained and total marks.
# Display the percentage.
# **bold text**

# %%
mark1 = float(input("Enter marks for subject 1: "))
mark2 = float(input("Enter marks for subject 2: "))
mark3 = float(input("Enter marks for subject 3: "))
mark4 = float(input("Enter marks for subject 4: "))
mark5 = float(input("Enter marks for subject 5: "))


total_marks = float(input("Enter total marks for all subjects: "))


obtained_marks = mark1 + mark2 + mark3 + mark4 + mark5

percentage = (obtained_marks / total_marks) * 100


print("Total Marks Obtained:", obtained_marks)
print("Percentage:", percentage, "%")
# Out:
# Enter marks for subject 1: 55
# Enter marks for subject 2: 60
# Enter marks for subject 3: 65
# Enter marks for subject 4: 70
# Enter marks for subject 5: 75
# Enter total marks for all subjects: 500
# Total Marks Obtained: 325.0
# Percentage: 65.0 %

# %% [markdown]
# 10.	Write a Python program to swap two numbers entered by the user without using a third variable.**bold text**

# %%
a = int(input("Enter first number (a): "))
b = int(input("Enter second number (b): "))


a, b = b, a


print("After swapping:")
print("First number (a):", a)
print("Second number (b):", b)
# Out:
# Enter first number (a): 23
# Enter second number (b): 32
# After swapping:
# First number (a): 32
# Second number (b): 23

# %% [markdown]
# 11.	Take a number as input and check whether it is even or odd.

# %%
# Program to check whether a number is even or odd


num = int(input("Enter a number: "))


if num % 2 == 0:
    print(num, "is an even number.")
else:
    print(num, "is an odd number.")
# Out:
# Enter a number: 5
# 5 is an odd number.

# %% [markdown]
# 12.	Write a Python program to convert temperature from Celsius to Fahrenheit using the formula: F = (C × 9/5) + 32.**bold text**

# %%
 celsius = float(input("Enter temperature in Celsius: "))


fahrenheit = (celsius * 9/5) + 32


print("{celsius}°C is equal to {fahrenheit}°F")
# Out:
# Enter temperature in Celsius: 12
# 12.0°C is equal to 53.6°F

# %% [markdown]
# 13.	Write a Python program to convert temperature from Fahrenheit to Celsius using the formula: C = (F - 32) × 5/9.

# %%
fahrenheit = float(input("Enter temperature in Fahrenheit: "))


celsius = (fahrenheit - 32) * 5/9


print("{fahrenheit}°F is equal to {celsius:.2f}°C")
# Out:
# Enter temperature in Fahrenheit: 20
# 20.0°F is equal to -6.67°C

# %% [markdown]
# 14.	Take two numbers as input and find their greatest common divisor (GCD).

# %% [markdown]
# 15.	Write a Python program to calculate the simple interest using the formula: SI = (P × R × T) / 100, where P is the principal amount, R is the rate of interest, and T is the time in years.

# %%
P = float(input("Enter the principal amount: "))
R = float(input("Enter the rate of interest (%): "))
T = float(input("Enter the time (in years): "))


SI = (P * R * T) / 100


print("Simple Interest = {SI:.2f}")
# Out:
# Enter the principal amount: 2500000
# Enter the rate of interest (%): 9
# Enter the time (in years): 5
# Simple Interest = 1125000.00

# %% [markdown]
# 16.	Write a Python program to check whether a number is positive, negative, or zero.

# %%
num = float(input("Enter a number: "))


if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number: -7
# The number is negative.

# %% [markdown]
# 17.	Write a Python program to find the largest among three numbers entered by the user.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))


if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3


print("The largest number is: {largest}")
# Out:
# Enter first number: 5
# Enter second number: 6
# Enter third number: 7
# The largest number is: 7.0

# %% [markdown]
# 18.	Take a number as input and check whether it is a multiple of 5.

# %%
num = int(input("Enter a number: "))

# Check if the number is a multiple of 5
if num % 5 == 0:
    print("num is a multiple of 5.")
else:
    print("numis not a multiple of 5.")
# Out:
# Enter a number: 9
# numis not a multiple of 5.

# %% [markdown]
# 19.	Write a Python program to calculate the perimeter of a circle using the formula: perimeter = 2 * π * radius.

# %% [markdown]
# 20.	Write a Python program to check whether a number is divisible by both 3 and 5.

# %%
num = int(input("Enter a number: "))


if (num % 3 == 0) and (num % 5 == 0):
    print("num is divisible by both 3 and 5.")
else:
    print("num is not divisible by both 3 and 5.")
# Out:
# Enter a number: 16
# num is not divisible by both 3 and 5.
